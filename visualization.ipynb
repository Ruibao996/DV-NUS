# %%
import pandas as pd
import pygwalker as pyg
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/liruifeng/Desktop/NUS-DV/project/result/data/daily_followers.csv')
df['tradeTime'] = pd.to_datetime(df['tradeTime'])

plt.figure(figsize=(10, 6))

plt.plot(df['tradeTime'], df['followers'], label='Followers')
plt.plot(df['tradeTime'], df['followers_rolling'], label='Followers Rolling Average')

plt.legend()

plt.title('Followers and Followers Rolling Average Over Time')
plt.xlabel('Trade Time')
plt.ylabel('Followers')

plt.show()

# %%
# cluster_centriods visualization

df = pd.read_csv('./result/data/cluster_centroids.csv')
pyg.walk(df, kernel_computation=True)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00061cc6c53b2fea5Se0RFiLNyK8cO79" style="height: auto">\n    <hea…

# %%
# pca_cluster visualization

df = pd.read_csv('./result/data/pca_clustered_result.csv')
pyg.walk(df, kernel_computation=True)
# Out:
# /var/folders/68/y816p_6x2018gj5z_9g2nwqr0000gn/T/ipykernel_15976/3005230.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./result/data/pca_clustered_result.csv')
# Box(children=(HTML(value='\n<div id="ifr-pyg-00061cc6c54517c3QWg3rEjHAJvPzTsL" style="height: auto">\n    <hea…

# %%
# daily_price visualization

df = pd.read_csv('./result/data/daily_prices.csv')
pyg.walk(df, kernel_computation=True)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00061cc6c54a79ecOWyfn56kCo8UBHhV" style="height: auto">\n    <hea…
